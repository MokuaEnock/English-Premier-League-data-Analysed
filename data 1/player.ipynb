# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("./players.csv")
df
# Out:
#       id                  name  now_cost position     team  own_goals  \
# 0      1   Cédric Alves Soares        42      DEF  Arsenal          0
# 1      3          Granit Xhaka        51      MID  Arsenal          0
# 2      4        Mohamed Elneny        42      MID  Arsenal          0
# 3      5           Rob Holding        42      DEF  Arsenal          0
# 4      6         Thomas Partey        48      MID  Arsenal          0
# ..   ...                   ...       ...      ...      ...        ...
# 670  625  Diego Da Silva Costa        55      FWD   Wolves          0
# 671  629       Boubacar Traoré        45      MID   Wolves          0
# 672  657         Nathan Fraser        45      FWD   Wolves          0
# 673  658      Harvey Griffiths        45      MID   Wolves          0
# 674  664      Dexter Lembikisa        40      DEF   Wolves          0
#
#      corners_and_indirect_freekicks_order  transfers_in  expected_assists  \
# ...
