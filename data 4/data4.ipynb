# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("player_data.csv")

# %%
df
# Out:
#      Unnamed: 0  playerId                age        id info.position  \
# 0             0  312586.0  21 years 286 days   63289.0             M
# 1             1  289629.0  24 years 306 days   13286.0             F
# 2             2  286397.0  25 years 175 days    9199.0             F
# 3             3  315737.0  23 years 171 days   42894.0             M
# 4             4  258884.0  24 years 314 days   13549.0             D
# ..          ...       ...                ...       ...           ...
# 882         882  319999.0  25 years 232 days   19620.0             M
# 883         883  186681.0  29 years 138 days   20750.0             M
# 884         884  288580.0  27 years 281 days    5175.0             D
# 885         885  267908.0   18 years 37 days  107891.0             G
# 886         886  288147.0  23 years 230 days   11419.0             M
#
#                           info.positionInfo nationalTeam.isoCode  \
# 0               Centre Attacking Midfielder                   US
# ...
